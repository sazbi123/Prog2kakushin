# %% [markdown]
# <a href="https://colab.research.google.com/github/sazbi123/Prog2kakushin/blob/main/work1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests as req
import re

#https://soundcloud.com/discover
url=input('URL : ')
url_s1=[]
url_s=[]
url_type=[]
low=1
lows=[]
r=req.get(url,timeout=3)
text1=r.text.split('\n')
for i in text1:
  url_s1=re.findall('"https://(.*?)"',i)
  url_s+=url_s1
for j in url_s:
  if ('.png' or '.jpg' or '.webp') in j:
    url_type.append('img')
  elif ('.js') in j:
    url_type.append('javascript')
  elif ('.css') in j:
    url_type.append('css')
  elif ('.mp3' or '.wav' or 'weba') in j:
    url_type.append('audio')
  elif ('.mp4' or '.avi' or '.webm') in j:
    url_type.append('video')
  else:
    url_type.append('None')
df=pd.DataFrame(url_s)
df[1]=pd.DataFrame(url_type)
df
# Out:
# URL : https://soundcloud.com/
#                                                     0           1
# 0   a-v2.sndcdn.com/assets/images/meta/soundcloud-...         img
# 1                                     soundcloud.com/        None
# 2   a-v2.sndcdn.com/assets/images/meta/soundcloud-...         img
# 3   a-v2.sndcdn.com/assets/images/meta/soundcloud-...         img
# 4                                     soundcloud.com/        None
# 5                                   m.soundcloud.com/        None
# 6   a-v2.sndcdn.com/assets/images/sc-icons/win8-2d...         img
# 7                                      soundcloud.com        None
# 8   a-v2.sndcdn.com/assets/images/sc-icons/favicon...        None
# 9   a-v2.sndcdn.com/assets/images/sc-icons/ios-a62...         img
# 10  a-v2.sndcdn.com/assets/images/sc-icons/fluid-b...         img
# 11                         dwt.soundcloud.com/tags.js  javascript
# 12  style.sndcdn.com/css/inter-43e88497e6ff16c818c...         css
# 13  a-v2.sndcdn.com/assets/css/app-6755b4f6eb6f013...         css
# 14  help.soundcloud.com/hc/articles/115003564308-T...        None
# 15                             www.microsoft.com/edge        None
# 16                                help.soundcloud.com        None
# 17              a-v2.sndcdn.com/assets/53-aed4402d.js  javascript
# 18              a-v2.sndcdn.com/assets/51-1af8fedb.js  javascript
# 19  cdn.cookielaw.org/consent/7e62c772-c97a-4d95-8...  javascript
# 20              a-v2.sndcdn.com/assets/16-6275c506.js  javascript
# 21              a-v2.sndcdn.com/assets/52-d33a6ec1.js  javascript
# 22               a-v2.sndcdn.com/assets/1-7f525fe3.js  javascript
# 23               a-v2.sndcdn.com/assets/3-816da9ef.js  javascript
# 24               a-v2.sndcdn.com/assets/2-28e86d69.js  javascript
# 25               a-v2.sndcdn.com/assets/0-a5487c9b.js  javascript
# 26              a-v2.sndcdn.com/assets/50-f37b1e03.js  javascript

# %%
for i in text1:
  if 'http' in i:
    url_s.append(i)
    lows.append(low)
  low+=1
